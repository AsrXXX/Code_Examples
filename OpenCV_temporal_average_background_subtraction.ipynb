# %%
#temporal subtraction simple
import numpy as np
import cv2
cap = cv2.VideoCapture('WiiPlay.mp4')
# Check if the webcam is opened correctly
if not cap.isOpened():
    raise IOError("Cannot open webcam")
first_frame, cur_frame, prev_frame = None, None, None
first_frame=cv2.resize(cap.read()[1], None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
img_sum=0
counter=0
while True:
    ret, frame = cap.read()
    prev_frame = cur_frame
    cur_frame = cv2.resize(frame, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
    #frame=frame.astype(np.float32)
    img_sum+=frame
    counter+=1
    b_frame=img_sum/counter
    #b_frame=b_frame.astype(np.ndarray)
    cv2.imshow('Background', b_frame)
    #print(frame)
    if prev_frame is not None:
        sub_frame = cv2.absdiff(cur_frame , prev_frame)
        cv2.imshow('1 subtraction', sub_frame)
        # 彩色圖轉灰階圖
        gray1 = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
        gray2 = cv2.cvtColor(cur_frame, cv2.COLOR_BGR2GRAY)

        # 高斯模糊化處理
        blur1 = cv2.GaussianBlur(gray1,(5,5),0)
        blur2 = cv2.GaussianBlur(gray2,(5,5),0)
        ret, th = cv2.threshold(result, 15, 255, cv2.THRESH_BINARY)
        result = cv2.absdiff(blur1, blur2)
        #erosion = cv2.erode(th, (3,3), iterations = 1)
        dilated = cv2.dilate(th, (10,10), iterations=1)
        cv2.imshow("diffShow",dilated)

        sub4_frame = cv2.absdiff(sub_frame, cur_frame)
        cv2.imshow('4 subtraction', sub4_frame)
    #if first_frame is not None:
        #sub2_frame = cv2.absdiff(cur_frame , first_frame)
        #cv2.imshow('2 subtraction', sub2_frame)
        #cv2.imshow('3 subtraction', first_frame)
    c = cv2.waitKey(1)
    if c == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
"""
進階動態偵測專案，透過時間平均法計算出動態背景。
並整合了高斯模糊、二值化與影像膨脹等管線技術，能有效過濾鏡頭雜訊並強化移動物體的輪廓。
"""
# Out:
# '\n進階動態偵測專案，透過時間平均法計算出動態背景。並整合了高斯模糊、二值化與影像膨脹等管線技術，能有效過濾鏡頭雜訊並強化移動物體的輪廓。\n'
